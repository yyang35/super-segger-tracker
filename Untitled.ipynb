# %%
# %matplotlib widget

# %%
import matplotlib.pyplot as plt
import PIL
from mpl_interactions import ioff, panhandler, zoom_factory
from PIL import Image

# %%
image = Image.open("/Users/sherryyang/wigginsLab/data/0814/images/211121_37C_10_1176_HU_timelapse002_prob211203_HU_t00001xy0c1.png")

# %%
# %matplotlib notebook
# Out:
# Warning: Cannot change to a different GUI toolkit: notebook. Using widget instead.

# %%
# %matplotlib widget
plt.ioff()
fig, ax = plt.subplots()
ax.imshow(image)
disconnect_zoom = zoom_factory(ax)
display(fig.canvas)
# Out:
# Canvas(capture_scroll=True, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back…

# %%
fig.canvas.draw()

# %%
fig.canvas

# %%
! pip install ncolor
# Out:
# Requirement already satisfied: ncolor in /Users/sherryyang/miniconda3/envs/omnipose/lib/python3.11/site-packages (1.2.1)
# Requirement already satisfied: numpy>=1.22.4 in /Users/sherryyang/miniconda3/envs/omnipose/lib/python3.11/site-packages (from ncolor) (1.24.4)
# Requirement already satisfied: scipy in /Users/sherryyang/miniconda3/envs/omnipose/lib/python3.11/site-packages (from ncolor) (1.11.1)
# Requirement already satisfied: numba in /Users/sherryyang/miniconda3/envs/omnipose/lib/python3.11/site-packages (from ncolor) (0.57.1)
# Requirement already satisfied: fastremap in /Users/sherryyang/miniconda3/envs/omnipose/lib/python3.11/site-packages (from ncolor) (1.13.5)
# Requirement already satisfied: scikit-image in /Users/sherryyang/miniconda3/envs/omnipose/lib/python3.11/site-packages (from ncolor) (0.21.0)
# Requirement already satisfied: mahotas>=1.4.13 in /Users/sherryyang/miniconda3/envs/omnipose/lib/python3.11/site-packages (from ncolor) (1.4.13)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/sherryyang/miniconda3/envs/omnipose/lib/python3.11/site-packages (from numba->ncolor) (0.40.1)
# Requirement already satisfied: networkx>=2.8 in /Users/sherryyang/miniconda3/envs/omnipose/lib/python3.11/site-packages (from scikit-image->ncolor) (3.1)
# Requirement already satisfied: pillow>=9.0.1 in /Users/sherryyang/miniconda3/envs/omnipose/lib/python3.11/site-packages (from scikit-image->ncolor) (10.0.0)
# Requirement already satisfied: imageio>=2.27 in /Users/sherryyang/miniconda3/envs/omnipose/lib/python3.11/site-packages (from scikit-image->ncolor) (2.31.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/sherryyang/miniconda3/envs/omnipose/lib/python3.11/site-packages (from scikit-image->ncolor) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/sherryyang/miniconda3/envs/omnipose/lib/python3.11/site-packages (from scikit-image->ncolor) (1.4.1)
# Requirement already satisfied: packaging>=21 in /Users/sherryyang/miniconda3/envs/omnipose/lib/python3.11/site-packages (from scikit-image->ncolor) (23.1)
# Requirement already satisfied: lazy_loader>=0.2 in /Users/sherryyang/miniconda3/envs/omnipose/lib/python3.11/site-packages (from scikit-image->ncolor) (0.3)

# %%
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
from segger_tracker import SeggerTracker
import ncolor
import glob

npzFiles = glob.glob("/Users/sherryyang/wigginsLab/data/0814/xy0/phase/*.npy")
for f in npzFiles:
    continue

# %%
def find_skeleton_centers(cell_count, gradient_total, threshold, regs_label):
    centers = {}
    for i in range(cell_count+1):
        masked = (regs_label == i) & (gradient_total < threshold)
        if not np.any(masked):
            continue
        #Skeleton of this cell
        y = np.ma.array(gradient_total * masked)
        row_indices, col_indices = np.where(y < 0)
        if(len(row_indices)<1):
            original_field = (regs_label == i)
            row_indices, col_indices = np.ma.where(original_field)
        #Find the geomerty center
        x_center = np.mean(row_indices)
        y_center = np.mean(col_indices)
        #Projected the geomerty center on skeleton
        distances = np.sqrt((row_indices - x_center)**2 + (col_indices - y_center)**2)
        closest_index = np.argmin(distances)
        closest_point = (row_indices[closest_index], col_indices[closest_index])
        #Found skeleton center
        centers[SeggerTracker.compress_xy(closest_point[1], closest_point[0])] = i
        
    return centers

# %%
npy_path = "/Users/sherryyang/wigginsLab/data/0820/xy0/phase/211121_37C_10_1176_HU_timelapse002_prob211203_HU_t00023xy0c1_seg.npy"
dat = np.load(npy_path, allow_pickle=True).item()
gradientsx = np.gradient(dat['flows'][-1][0])
gradientsy = np.gradient(dat['flows'][-1][1])
gradient_total = gradientsy[1] + gradientsx[0]
regs_label = dat['masks']
cell_num = np.max(regs_label)
centers = find_skeleton_centers(cell_num, gradient_total, -3, regs_label)

# %%
ncolor_masks = ncolor.label(regs_label)
# %matplotlib widget

plt.ioff()
fig, ax = plt.subplots(figsize=(14, 8))
ax.imshow(ncolor_masks)
fig.tight_layout()
plt.title(npy_path)

# Iterate through the dictionary and draw circles with labels
for position, label in centers.items():
    x, y = SeggerTracker.extract_xy(position)
    ax.text(x, y, str(label), color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='circle'), fontsize=8, horizontalalignment='center', verticalalignment='center')


disconnect_zoom = zoom_factory(ax)
display(fig.canvas)
# Out:
# Canvas(capture_scroll=True, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back…
