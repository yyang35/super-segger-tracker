# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
X = np.linspace(0, 2*np.pi, 100)
Y = np.cos(X)

fig,ax = plt.subplots()
ax.plot(X, Y, color='green')

plt.show()

# %%
# Importing required library
from mpl_interactions import ioff, panhandler, zoom_factory
import matplotlib.pyplot as plt
 
# %matplotlib widget
# creating the dataset
data = {'Operating System': 10, 'Data Structure': 7,
        'Machine Learning': 14, 'Deep Learning': 12}
courses = list(data.keys())
values = list(data.values())
# Enable scroll to zoom with the help of MPL
# Interactions library function like ioff and zoom_factory.
with plt.ioff():
    figure, axis = plt.subplots()
# creating the bar plot
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.bar(courses, values, color='green', width=0.4)
disconnect_zoom = zoom_factory(axis)
# Enable scrolling and panning with the help of MPL
# Interactions library function like panhandler.
pan_handler = panhandler(figure)
display(figure.canvas)
# Out:
# Canvas(capture_scroll=True, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back…

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import PIL

from mpl_interactions import ioff, panhandler, zoom_factory

# %%
# A sample image
image = np.array(PIL.Image.open(urllib.request.urlopen('https://raw.githubusercontent.com/matplotlib/matplotlib/v3.3.0/lib/matplotlib/mpl-data/sample_data/ada.png')))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # A sample image
# ----> 2 image = np.array(PIL.Image.open(urllib.request.urlopen('https://raw.githubusercontent.com/matplotlib/matplotlib/v3.3.0/lib/matplotlib/mpl-data/sample_data/ada.png')))
#
# NameError: name 'urllib' is not defined

# %%
from PIL import Image

# %%
image = Image.open("/Users/sherryyang/wigginsLab/data/0814/images/211121_37C_10_1176_HU_timelapse002_prob211203_HU_t00001xy0c1.png")

# %%
with ioff:
    fig, ax = plt.subplots()
fig.canvas.toolbar.push_current()
ax.imshow(image)
disconnect_zoom = zoom_factory(ax)
display(fig.canvas)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_interactions import panhandler, scrollhandler

# Generate some random data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a Matplotlib figure and axis
fig, ax = plt.subplots()

# Plot the data
line, = ax.plot(x, y, label='sin(x)')

# Add interactive scrolling and panning using mpl-interactions
scrollhandler(fig)
panhandler(fig)

# Add labels and legend
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.legend()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from mpl_interactions import panhandler, scrollhandler
#       5 # Generate some random data
#       6 x = np.linspace(0, 10, 100)
#
# ImportError: cannot import name 'scrollhandler' from 'mpl_interactions' (/Users/sherryyang/miniconda3/envs/omnipose/lib/python3.11/site-packages/mpl_interactions/__init__.py)
